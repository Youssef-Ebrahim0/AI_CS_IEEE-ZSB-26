# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
#%reload_ext autoreload

import pandas as pd
import numpy as np

from utils import randomize, draw_learning_curves
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC

# %%
# Import data from csv file
data = pd.read_csv('data.csv')

# %%
# Fix random seed
np.random.seed(55)

# Prepare features and label data
X = np.array(data[['x1', 'x2']])
y = np.array(data['y'])

# %% [markdown]
# ### Uncomment the code for each one, and examine the learning curve that gets drawn.

# %%
# TODO: Uncomment one of the three classifiers, and hit "Test Run"
# to see the learning curve. Use these to answer the quiz below.

### Logistic Regression
estimator = LogisticRegression()

### Decision Tree
#estimator = GradientBoostingClassifier() -> normal

### Support Vector Machine
#estimator = SVC(kernel='rbf', gamma=1000) -> overfit

# %%
draw_learning_curves(X, y, estimator, 10)

# %% [markdown]
# Quiz Question
#
# From the models above, which model underfits, which one overfits, and which one is just right?
#
# Logistic Regression
#
# Decision Tree
#
# Support Vector Machine

# %% [markdown]
# Enter Answers Here:

# %% [markdown]
# .underfitting

# %% [markdown]
# .well fit

# %% [markdown]
# .overfitting
