# %% [markdown]
# ### Boston Housing Data
#
# In order to gain a better understanding of the metrics used in regression settings, we will be looking at the Boston Housing dataset.
#
# First use the cell below to read in the dataset and set up the training and testing data that will be used for the rest of this problem.

# %%
import pandas as pd # Import pandas to read CSV files
# from sklearn.datasets import fetch_california_housing # Commenting out due to download error
from sklearn.model_selection import train_test_split # Keep if we still need to split from a single dataset
import numpy as np
# import tests2 as t # Commenting out as 'tests2' module was not found

# Load the training and testing datasets from the provided CSV files
train_df = pd.read_csv('/content/sample_data/california_housing_train.csv')
test_df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# Assuming 'median_house_value' is the target column in the California Housing CSVs
# Separate features (X) and target (y) for the training set
y_train = train_df['median_house_value']
X_train = train_df.drop('median_house_value', axis=1)

# Separate features (X) and target (y) for the testing set
y_test = test_df['median_house_value']
X_test = test_df.drop('median_house_value', axis=1)

# The original problem statement indicates that a single X and y were split.
# To maintain consistency, we can combine the train/test data to create a full X and y,
# then split it again with the same random_state as before.
# This ensures the splits are reproducible as per the original problem's intention,
# even though the CSVs are already split.

# Combine for full dataset (optional, but good for consistency with original problem logic)
# Assuming feature columns are consistent across train_df and test_df
# Also assuming the original split was 33% test size, so the `train_test_split` might overwrite the CSV split.
# To strictly adhere to the original problem structure of *starting* with X, y and then splitting:

full_df = pd.concat([train_df, test_df])
X = full_df.drop('median_house_value', axis=1)
y = full_df['median_house_value']

# Re-apply the original train_test_split to ensure consistent split ratios and random state
X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=0.33, random_state=42)

# %% [markdown]
# > **Step 1:** Before we get too far, let's do a quick check of the models that you can use in this situation given that you are working on a regression problem.  Use the dictionary and corresponding letters below to provide all the possible models you might choose to use.

# %%
# When can you use the model - use each option as many times as necessary
a = 'regression'
b = 'classification'
c = 'both regression and classification'

models = {
    'decision trees': c, # letter here
    'random forest': c, # letter here
    'adaptive boosting': c, # letter here
    'logistic regression': b, # letter here
    'linear regression': a # letter here
}

#checks your answer, no need to change this code
t.q1_check(models)
# Out:
# That's right!  All but logistic regression can be used for predicting numeric values.  And linear regression is the only one of these that you should not use for predicting categories.  Technically sklearn won't stop you from doing most of anything you want, but you probably want to treat cases in the way you found by answering this question!

# %% [markdown]
# > **Step 2:** Now for each of the models you found in the previous question that can be used for regression problems, import them using sklearn.

# %%
# Import models from sklearn - notice you will want to use
# the regressor version (not classifier) - googling to find
# each of these is what we all do!
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# > **Step 3:** Now that you have imported the 4 models that can be used for regression problems, instantate each below.

# %%
# Instantiate each of the models you imported
# For now use the defaults for all the hyperparameters
dtr = DecisionTreeRegressor()
rfr = RandomForestRegressor()
abr = AdaBoostRegressor()
lr = LinearRegression()

# %% [markdown]
# > **Step 4:** Fit each of your instantiated models on the training data.

# %%
# Fit each of your models using the training data
dtr.fit(X_train, y_train)
rfr.fit(X_train, y_train)
abr.fit(X_train, y_train)
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# > **Step 5:** Use each of your models to predict on the test data.

# %%
# Predict on the test values for each model
preds_DTR = dtr.predict(X_test)
preds_RFR = rfr.predict(X_test)
preds_ABR = abr.predict(X_test)
preds_LR = lr.predict(X_test)

# %% [markdown]
# > **Step 6:** Now for the information related to this lesson.  Use the dictionary to match the metrics that are used for regression and those that are for classification.

# %%
# potential model options
a = 'regression'
b = 'classification'
c = 'both regression and classification'

#
metrics = {
    'precision': b, # letter here
    'recall': b,# letter here
    'accuracy': b,# letter here
    'r2_score': a,# letter here
    'mean_squared_error': a,# letter here
    'area_under_curve': b, # letter here
    'mean_absolute_area' : a # letter here
}

#checks your answer, no need to change this code
t.q6_check(metrics)
# Out:
# That's right! Looks like you know your metrics!

# %% [markdown]
# > **Step 6:** Now that you have identified the metrics that can be used in for regression problems, use sklearn to import them.

# %%
# Import the metrics from sklearn
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# > **Step 7:** Similar to what you did with classification models, let's make sure you are comfortable with how exactly each of these metrics is being calculated.  We can then match the value to what sklearn provides.

# %%
def r2(actual, preds):
    '''
    INPUT:
    actual - numpy array or pd series of actual y values
    preds - numpy array or pd series of predicted y values
    OUTPUT:
    returns the r-squared score as a float
    '''
    ss_res = np.sum((actual - preds) ** 2)
    ss_tot = np.sum((actual - np.mean(actual)) ** 2)
    return 1 - (ss_res / ss_tot)

# Check solution matches sklearn
print(r2(y_test, preds_DTR))
print(r2_score(y_test, preds_DTR))
print("Since the above match, we can see that we have correctly calculated the r2 value.")
# Out:
# 0.6370036580940692
# 0.6370036580940692
# Since the above match, we can see that we have correctly calculated the r2 value.

# %% [markdown]
# > **Step 8:** Your turn fill in the function below and see if your result matches the built in for mean_squared_error.

# %%
def mse(actual, preds):
    '''
    INPUT:
    actual - numpy array or pd series of actual y values
    preds - numpy array or pd series of predicted y values
    OUTPUT:
    returns the mean squared error as a float
    '''
    return np.mean((actual - preds) ** 2)  # calculate mse here


# Check your solution matches sklearn
print(mse(y_test, preds_DTR))
print(mean_squared_error(y_test, preds_DTR))
print("If the above match, you are all set!")
# Out:
# 4878622330.860909
# 4878622330.860909
# If the above match, you are all set!

# %% [markdown]
# > **Step 9:** Now one last time - complete the function related to mean absolute error.  Then check your function against the sklearn metric to assure they match.

# %%
def mae(actual, preds):
    '''
    INPUT:
    actual - numpy array or pd series of actual y values
    preds - numpy array or pd series of predicted y values
    OUTPUT:
    returns the mean absolute error as a float
    '''

    return np.mean(np.abs(actual - preds)) # calculate the mae here

# Check your solution matches sklearn
print(mae(y_test, preds_DTR))
print(mean_absolute_error(y_test, preds_DTR))
print("If the above match, you are all set!")
# Out:
# 44387.66393939394
# 44387.66393939394
# If the above match, you are all set!

# %% [markdown]
# > **Step 10:** Which model performed the best in terms of each of the metrics?  Note that r2 and mse will always match, but the mae may give a different best model.  Use the dictionary and space below to match the best model via each metric.

# %%
#match each metric to the model that performed best on it
a = 'decision tree'
b = 'random forest'
c = 'adaptive boosting'
d = 'linear regression'


best_fit = {
    'mse': b, # letter here
    'r2': b, # letter here
    'mae': b # letter here
}

#Tests your answer - don't change this code
t.check_ten(best_fit)
# Out:
# That's right!  The random forest was best in terms of all the metrics this time!

# %%
# cells for work
